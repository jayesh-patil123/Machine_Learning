# %%
import pandas as pd
import numpy as np

# %%
car = pd.read_csv(r"car_price.csv")

# %%
car
# Out:
#      symboling normalized_losses Fuel_type   make num_of_doors   aspiration  \
# 0            3                 ?       gas    std          two  convertible
# 1            3                 ?       gas    std          two  convertible
# 2            1                 ?       gas    std          two    hatchback
# 3            2               164       gas    std         four        sedan
# 4            2               164       gas    std         four        sedan
# ..         ...               ...       ...    ...          ...          ...
# 200         -1                95       gas    std         four        sedan
# 201         -1                95       gas  turbo         four        sedan
# 202         -1                95       gas    std         four        sedan
# 203         -1                95    diesel  turbo         four        sedan
# 204         -1                95       gas  turbo         four        sedan
#
#     wheel_base engine_location  drive_wheels   body_style  ...  engine_size  \
# 0          rwd           front          88.6  alfa-romero  ...          130
# 1          rwd           front          88.6  alfa-romero  ...          130
# 2          rwd           front          94.5  alfa-romero  ...          152
# 3          fwd           front          99.8         audi  ...          109
# 4          4wd           front          99.4         audi  ...          136
# ..         ...             ...           ...          ...  ...          ...
# 200        rwd           front         109.1        volvo  ...          141
# 201        rwd           front         109.1        volvo  ...          141
# 202        rwd           front         109.1        volvo  ...          173
# 203        rwd           front         109.1        volvo  ...          145
# 204        rwd           front         109.1        volvo  ...          141
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 0           mpfi  3.47    2.68               9.0        111      5000
# 1           mpfi  3.47    2.68               9.0        111      5000
# 2           mpfi  2.68    3.47               9.0        154      5000
# 3           mpfi  3.19     3.4              10.0        102      5500
# 4           mpfi  3.19     3.4               8.0        115      5500
# ..           ...   ...     ...               ...        ...       ...
# 200         mpfi  3.78    3.15               9.5        114      5400
# 201         mpfi  3.78    3.15               8.7        160      5300
# 202         mpfi  3.58    2.87               8.8        134      5500
# 203          idi  3.01     3.4              23.0        106      4800
# 204         mpfi  3.78    3.15               9.5        114      5400
#
#     city_mpg highway_mpg  price
# 0         21          27  13495
# 1         21          27  16500
# 2         19          26  16500
# 3         24          30  13950
# 4         18          22  17450
# ..       ...         ...    ...
# 200       23          28  16845
# 201       19          25  19045
# 202       18          23  21485
# 203       26          27  22470
# 204       19          25  22625
#
# [205 rows x 26 columns]

# %%
car.shape
# Out:
# (205, 26)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    object
#  2   Fuel_type          205 non-null    object
#  3   make               205 non-null    object
#  4   num_of_doors       205 non-null    object
#  5   aspiration         205 non-null    object
#  6   wheel_base         205 non-null    object
#  7   engine_location    205 non-null    object
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
#  16  engine_size        205 non-null    int64
#  17  fuel_system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression_ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak_rpm           205 non-null    object
#  23  city_mpg           205 non-null    int64
#  24  highway_mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
car.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# Fuel_type            0
# make                 0
# num_of_doors         0
# aspiration           0
# wheel_base           0
# engine_location      0
# drive_wheels         0
# body_style           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
car[car.select_dtypes(include = ['object']).columns] = car[car.select_dtypes(include = ['object']).columns].apply(le.fit_transform)

# %%
car.head()
# Out:
#    symboling  normalized_losses  Fuel_type  make  num_of_doors  aspiration  \
# 0          3                 51          1     0             2           0
# 1          3                 51          1     0             2           0
# 2          1                 51          1     0             2           2
# 3          2                 27          1     0             1           3
# 4          2                 27          1     0             1           3
#
#    wheel_base  engine_location  drive_wheels  body_style  ...  engine_size  \
# 0           2                0          88.6           0  ...          130
# 1           2                0          88.6           0  ...          130
# 2           2                0          94.5           0  ...          152
# 3           1                0          99.8           1  ...          109
# 4           0                0          99.4           1  ...          136
#
#    fuel_system  bore  stroke  compression_ratio  horsepower  peak_rpm  \
# 0            5    23       4                9.0           5        10
# 1            5    23       4                9.0           5        10
# 2            5     1      27                9.0          20        10
# 3            5    13      24               10.0           2        16
# 4            5    13      24                8.0           8        16
#
#    city_mpg  highway_mpg  price
# 0        21           27     31
# 1        21           27     50
# 2        19           26     50
# 3        24           30     36
# 4        18           22     61
#
# [5 rows x 26 columns]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    int32
#  2   Fuel_type          205 non-null    int32
#  3   make               205 non-null    int32
#  4   num_of_doors       205 non-null    int32
#  5   aspiration         205 non-null    int32
#  6   wheel_base         205 non-null    int32
#  7   engine_location    205 non-null    int32
#  8   drive_wheels       205 non-null    float64
#  9   body_style         205 non-null    int32
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    int32
#  15  num_of_cylinders   205 non-null    int32
#  16  engine_size        205 non-null    int64
#  17  fuel_system        205 non-null    int32
#  18  bore               205 non-null    int32
#  19  stroke             205 non-null    int32
#  20  compression_ratio  205 non-null    float64
#  21  horsepower         205 non-null    int32
#  22  peak_rpm           205 non-null    int32
#  23  city_mpg           205 non-null    int64
#  24  highway_mpg        205 non-null    int64
#  25  price              205 non-null    int32
# dtypes: float64(5), int32(16), int64(5)
# memory usage: 29.0 KB

# %%
car.describe()
# Out:
#         symboling  normalized_losses   Fuel_type        make  num_of_doors  \
# count  205.000000         205.000000  205.000000  205.000000    205.000000
# mean     0.834146          29.853659    0.902439    0.180488      1.424390
# std      1.245307          17.197470    0.297446    0.385535      0.514867
# min     -2.000000           0.000000    0.000000    0.000000      0.000000
# 25%      0.000000          15.000000    1.000000    0.000000      1.000000
# 50%      1.000000          28.000000    1.000000    0.000000      1.000000
# 75%      2.000000          48.000000    1.000000    0.000000      2.000000
# max      3.000000          51.000000    1.000000    1.000000      2.000000
#
#        aspiration  wheel_base  engine_location  drive_wheels  body_style  ...  \
# count  205.000000  205.000000       205.000000    205.000000  205.000000  ...
# mean     2.614634    1.326829         0.014634     98.756585   12.195122  ...
# std      0.859081    0.556171         0.120377      6.021776    6.274831  ...
# min      0.000000    0.000000         0.000000     86.600000    0.000000  ...
# 25%      2.000000    1.000000         0.000000     94.500000    8.000000  ...
# 50%      3.000000    1.000000         0.000000     97.000000   12.000000  ...
# 75%      3.000000    2.000000         0.000000    102.400000   19.000000  ...
# max      4.000000    2.000000         1.000000    120.900000   21.000000  ...
#
#        engine_size  fuel_system        bore      stroke  compression_ratio  \
# count   205.000000   205.000000  205.000000  205.000000         205.000000
# mean    126.907317     3.253659   18.336585   19.551220          10.142537
# std      41.642693     2.013204   10.368640    8.898863           3.972040
# min      61.000000     0.000000    0.000000    0.000000           7.000000
# 25%      97.000000     1.000000   11.000000   13.000000           8.600000
# 50%     120.000000     5.000000   16.000000   21.000000           9.000000
# 75%     141.000000     5.000000   28.000000   25.000000           9.400000
# max     326.000000     7.000000   38.000000   36.000000          23.000000
#
#        horsepower    peak_rpm    city_mpg  highway_mpg       price
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean    31.726829   11.604878   25.219512    30.751220   96.648780
# std     18.572949    5.318758    6.542142     6.886443   54.675007
# min      0.000000    0.000000   13.000000    16.000000    0.000000
# 25%     12.000000    8.000000   19.000000    25.000000   50.000000
# 50%     40.000000   12.000000   24.000000    30.000000   99.000000
# 75%     47.000000   16.000000   30.000000    34.000000  144.000000
# max     59.000000   23.000000   49.000000    54.000000  186.000000
#
# [8 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
car_train, car_test = train_test_split(car,test_size=0.2)

# %%
car_train_x = car_train.iloc[:,0:-1]
car_train_y = car_train.iloc[:,-1]

# %%
car_train_x
# Out:
#      symboling  normalized_losses  Fuel_type  make  num_of_doors  aspiration  \
# 164          1                 28          1     0             2           2
# 30           2                 18          1     0             2           2
# 72           3                 19          1     0             2           0
# 15           0                 51          1     0             1           3
# 140          2                 41          1     0             2           2
# ..         ...                ...        ...   ...           ...         ...
# 83           3                 51          1     1             2           2
# 24           1                 21          1     0             1           2
# 102          0                  6          1     0             1           4
# 195         -1                 37          1     0             1           4
# 146          0                 44          1     0             1           4
#
#      wheel_base  engine_location  drive_wheels  body_style  ...  \
# 164           2                0          94.5          19  ...
# 30            1                0          86.6           5  ...
# 72            2                0          96.6           9  ...
# 15            2                0         103.5           2  ...
# 140           0                0          93.3          18  ...
# ..          ...              ...           ...         ...  ...
# 83            1                0          95.9          11  ...
# 24            1                0          93.7           4  ...
# 102           1                0         100.4          12  ...
# 195           2                0         104.3          21  ...
# 146           1                0          97.0          18  ...
#
#      num_of_cylinders  engine_size  fuel_system  bore  stroke  \
# 164                 2           98            1    13       9
# 30                  2           92            0     2      25
# 72                  0          234            5    22      12
# 15                  3          209            5    30      23
# 140                 2          108            1    30       3
# ..                ...          ...          ...   ...     ...
# 83                  2          156            6    27      33
# 24                  2           90            1     4      19
# 102                 3          181            5    21      20
# 195                 2          141            5    35      15
# 146                 2          108            1    30       3
#
#      compression_ratio  horsepower  peak_rpm  city_mpg  highway_mpg
# 164                9.0          44         8        29           34
# 30                 9.6          38         8        49           54
# 72                 8.3          21         7        16           18
# 15                 8.0          28        15        16           22
# 140                8.7          46         4        26           31
# ..                 ...         ...       ...       ...          ...
# 83                 7.0          18        10        19           24
# 24                 9.4          42        16        31           38
# 102                9.0          19        12        17           22
# 195                9.5           7        15        23           28
# 146                9.0          49         8        28           32
#
# [164 rows x 25 columns]

# %%
car_train_y
# Out:
# 164    157
# 30     114
# 72      92
# 15      86
# 140    140
#       ...
# 83      39
# 24     110
# 102     37
# 195     30
# 146    138
# Name: price, Length: 164, dtype: int32

# %%
car_test_x = car_test.iloc[:,0:-1]
car_test_y = car_test.iloc[:,-1]

# %%
car_test_x
# Out:
#      symboling  normalized_losses  Fuel_type  make  num_of_doors  aspiration  \
# 194         -2                  2          1     0             1           3
# 158          0                 46          0     0             1           3
# 1            3                 51          1     0             2           0
# 32           1                  0          1     0             2           2
# 173         -1                 36          1     0             1           3
# 89           1                 15          1     0             2           3
# 9            0                 51          1     1             2           2
# 84           3                 51          1     1             2           2
# 78           2                 26          1     0             2           2
# 91           1                 15          1     0             2           3
# 22           1                 10          1     0             2           2
# 160          0                 46          1     0             1           3
# 185          2                 48          1     0             1           3
# 184          2                 48          0     0             1           3
# 33           1                  0          1     0             2           2
# 116          0                 26          0     1             1           3
# 61           1                 16          1     0             2           2
# 49           0                 51          1     0             2           3
# 14           1                 51          1     0             1           3
# 29           3                 20          1     1             2           2
# 136          3                 22          1     1             2           2
# 13           0                 30          1     0             1           3
# 172          2                 17          1     0             2           0
# 92           1                 13          1     0             1           3
# 117          0                 26          1     1             1           3
# 100          0                  4          1     0             1           3
# 95           1                 15          1     0             2           2
# 163          1                 28          1     0             2           3
# 87           1                 14          1     1             1           3
# 57           3                 22          1     0             2           2
# 35           0                  7          1     0             1           3
# 6            1                 25          1     0             1           3
# 58           3                 22          1     0             2           2
# 108          0                 26          0     1             1           3
# 4            2                 27          1     0             1           3
# 167          2                 17          1     0             2           1
# 168          2                 17          1     0             2           1
# 101          0                 15          1     0             1           3
# 25           1                 21          1     0             1           3
# 62           0                  9          1     0             1           3
# 176         -1                 36          1     0             1           3
#
#      wheel_base  engine_location  drive_wheels  body_style  ...  \
# 194           2                0         104.3          21  ...
# 158           1                0          95.7          19  ...
# 1             2                0          88.6           0  ...
# 32            1                0          93.7           5  ...
# 173           1                0         102.4          19  ...
# 89            1                0          94.5          12  ...
# 9             0                0          99.5           1  ...
# 84            1                0          95.9          11  ...
# 78            1                0          93.7          11  ...
# 91            1                0          94.5          12  ...
# 22            1                0          93.7           4  ...
# 160           1                0          95.7          19  ...
# 185           1                0          97.3          20  ...
# 184           1                0          97.3          20  ...
# 33            1                0          93.7           5  ...
# 116           2                0         107.9          13  ...
# 61            1                0          98.8           8  ...
# 49            2                0         102.0           7  ...
# 14            2                0         103.5           2  ...
# 29            1                0          95.9           4  ...
# 136           1                0          99.1          17  ...
# 13            2                0         101.2           2  ...
# 172           2                0          98.4          19  ...
# 92            1                0          94.5          12  ...
# 117           2                0         108.0          13  ...
# 100           1                0          97.2          12  ...
# 95            1                0          94.5          12  ...
# 163           2                0          94.5          19  ...
# 87            1                0          96.3          11  ...
# 57            2                0          95.3           8  ...
# 35            1                0          96.5           5  ...
# 6             1                0         105.8           1  ...
# 58            2                0          95.3           8  ...
# 108           2                0         107.9          13  ...
# 4             0                0          99.4           1  ...
# 167           2                0          98.4          19  ...
# 168           2                0          98.4          19  ...
# 101           1                0         100.4          12  ...
# 25            1                0          93.7           4  ...
# 62            1                0          98.8           8  ...
# 176           1                0         102.4          19  ...
#
#      num_of_cylinders  engine_size  fuel_system  bore  stroke  \
# 194                 2          141            5    35      15
# 158                 2          110            3    15      22
# 1                   2          130            5    23       4
# 32                  2           79            0     2      10
# 173                 2          122            5    16      30
# 89                  2           97            1    11      21
# 9                   1          131            5    10      24
# 84                  2          156            6    27      33
# 78                  2           92            1     4      19
# 91                  2           97            1    11      21
# 22                  2           90            1     4      19
# 160                 2           98            1    13       9
# 185                 2          109            5    13      24
# 184                 2           97            3     6      24
# 33                  2           92            0     2      25
# 116                 2          152            3    32      29
# 61                  2          122            1    20      23
# 49                  5          326            5    25       5
# 14                  3          164            5    16      17
# 29                  2          156            4    28      34
# 136                 2          121            5    25      10
# 13                  3          164            5    16      17
# 172                 2          146            5    30      28
# 92                  2           97            1    11      21
# 117                 2          134            5    29      18
# 100                 2          120            1    17      27
# 95                  2           97            1    11      21
# 163                 2           98            1    13       9
# 87                  2          110            6    12      26
# 57                  6           70            2    38      36
# 35                  2           92            0     2      25
# 6                   1          136            5    13      24
# 58                  6           80            5    38      36
# 108                 2          152            3    32      29
# 4                   1          136            5    13      24
# 167                 2          146            5    30      28
# 168                 2          146            5    30      28
# 101                 3          181            5    21      20
# 25                  2           90            1     4      19
# 62                  2          122            1    20      23
# 176                 2          122            5    16      30
#
#      compression_ratio  horsepower  peak_rpm  city_mpg  highway_mpg
# 194                9.5           7        15        23           28
# 158               22.5          37         5        34           36
# 1                  9.0           5        10        21           27
# 32                10.1          39        16        38           42
# 173                8.7          55         1        29           34
# 89                 9.4          43        12        31           37
# 9                  7.0          23        16        16           22
# 84                 7.0          18        10        19           24
# 78                 9.4          42        16        31           38
# 91                 9.4          43        12        31           37
# 22                 9.4          42        16        31           38
# 160                9.0          44         8        38           47
# 185                9.0          51        13        27           34
# 184               23.0          35         8        37           46
# 33                 9.2          47        21        30           34
# 116               21.0          57         0        28           33
# 61                 8.6          50         8        26           32
# 49                11.5          32        10        13           17
# 14                 9.0          11         2        20           25
# 29                 7.0          18        10        19           24
# 136                9.0          23        16        19           26
# 13                 9.0          11         2        21           28
# 172                9.3           9         8        24           30
# 92                 9.4          43        12        31           37
# 117                7.0          16        17        18           24
# 100                8.5          58        12        27           34
# 95                 9.4          43        12        31           37
# 163                9.0          44         8        29           34
# 87                 7.5           9        16        23           30
# 57                 9.4           1        21        17           23
# 35                 9.2          47        21        30           34
# 6                  8.5           4        16        19           25
# 58                 9.4          14        21        16           23
# 108               21.0          57         0        28           33
# 4                  8.0           8        16        18           22
# 167                9.3           9         8        24           30
# 168                9.3           9         8        24           30
# 101                9.0          19        12        17           22
# 25                 9.4          42        16        31           38
# 62                 8.6          50         8        26           32
# 176                8.7          55         1        27           32
#
# [41 rows x 25 columns]

# %%
car_test_y
# Out:
# 194     25
# 158    148
# 1       50
# 32     105
# 173    167
# 89     106
# 9      186
# 84      38
# 78     119
# 91     118
# 22     113
# 160    143
# 185    156
# 184    151
# 33     116
# 116     64
# 61       4
# 49      94
# 14      82
# 29      27
# 136     65
# 13      76
# 172     62
# 92     124
# 117     65
# 100    177
# 95     146
# 163    154
# 87     172
# 57      33
# 35     134
# 6       63
# 58      44
# 108     28
# 4       61
# 167    160
# 168    178
# 101     32
# 25     120
# 62       1
# 176      7
# Name: price, dtype: int32

# %%
# Building the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(car_train_x , car_train_y)
# Out:
# LinearRegression()

# %%
pred_train = lr.predict(car_train_x)
pred_test = lr.predict(car_test_x)

# %%
err_test = car_test_y - pred_test
err_test
# Out:
# 194    -42.060585
# 158     44.177941
# 1       22.712395
# 32     -26.486502
# 173     70.482952
# 89     -37.814706
# 9       94.486425
# 84     -39.349943
# 78     -27.464029
# 91     -24.322788
# 22     -29.661104
# 160     -6.338701
# 185     47.031132
# 184     41.062437
# 33     -46.003353
# 116    -19.898744
# 61    -105.972541
# 49      24.268015
# 14      80.732264
# 29     -63.652722
# 136     -6.595973
# 13      29.898346
# 172     38.399383
# 92      -8.899007
# 117    -21.270315
# 100     27.819120
# 95      21.721508
# 163     18.925164
# 87      69.396658
# 57      42.168142
# 35     -11.122994
# 6        1.964220
# 58      67.466955
# 108    -58.728243
# 4      -10.475086
# 167     98.181796
# 168    115.976014
# 101    -31.270479
# 25     -20.642159
# 62    -115.080251
# 176    -86.284670
# Name: price, dtype: float64

# %%
# Rsquare

# %%
Rsquare = lr.score(car_train_x , car_train_y)
Rsquare
# Out:
# 0.418669404561023

# %%
N = car_train_x.shape[0]
K = car_train_x.shape[1]

# %%
adj_Rsquare = 1-(1-Rsquare)*(N-1)/(N-K-1)
adj_Rsquare
# Out:
# 0.31335589089454163

# %%
lr.coef_
# Out:
# array([-4.03632992e+00, -1.72020314e-01, -1.86144207e+02,  1.75865548e+00,
#         8.73891265e+00,  1.40722023e+01, -2.48060713e+00, -1.99310429e+00,
#         4.47988728e-01,  2.04230286e+00, -1.44346618e+00,  2.29017546e+00,
#        -1.76662005e+00, -5.14454369e-02, -5.36969494e+00, -1.23350265e+01,
#         7.53185239e-01, -8.53372213e+00, -5.36667841e-01, -1.80732197e-01,
#        -1.29794358e+01,  3.61886508e-01,  1.79588765e+00, -4.98220180e+00,
#         4.33479129e+00])

# %%
lr.intercept_
# Out:
# 563.3806584257986

# %%
mse = np.mean(np.square(err_test))
mse
# Out:
# 2864.3621261817843

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 53.51973585680131

# %%
mape = np.mean(np.abs(err_test*100/car_test_y))
mape
# Out:
# 425.58247172042337

# %%
err_train = car_train_y - pred_train
err_train
# Out:
# 164    37.797956
# 30    -20.352367
# 72     30.582883
# 15     15.000814
# 140    22.520822
#          ...
# 83    -38.607170
# 24    -17.701757
# 102   -25.597659
# 195   -32.502797
# 146    13.158282
# Name: price, Length: 164, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(err_test, '.')

# %%
plt.hist(err_train, bins=70, edgecolor='r');

# %%
pred_actual_df = pd.DataFrame()

# %%
pred_actual_df['Actual'] = car_train_y
pred_actual_df['Predicted'] = pred_train

# %%
pred_actual_df
# Out:
#      Actual   Predicted
# 164     157  119.202044
# 30      114  134.352367
# 72       92   61.417117
# 15       86   70.999186
# 140     140  117.479178
# ..      ...         ...
# 83       39   77.607170
# 24      110  127.701757
# 102      37   62.597659
# 195      30   62.502797
# 146     138  124.841718
#
# [164 rows x 2 columns]

# %%
import seaborn as sns

# %%
sns.jointplot(x='Actual', y='Predicted', data= pred_actual_df , kind='reg')
